# %% [markdown]
# <a href="https://colab.research.google.com/github/mathcute/Data-Science/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Grafico sobre gdp(PIB)

# %%
from matplotlib import pyplot as plt

years = [1920, 2000, 1930, 1976, 2004, 1950, 1944]

gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color = 'black', marker = 'o', linestyle = 'solid')

plt.title('Nominal GDP')

plt.ylabel('Billions of $')
plt.show()
